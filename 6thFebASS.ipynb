# %% [markdown]
# Q2

# %%
# Q2. Write a python program for encrypting a message sent to you by your friend. The logic of encryption 
# should be such that, for a the output should be z. For b, the output should be y. For c, the output should 
# be x respectively. Also, the whitespace should be replaced with a dollar sign. Keep the punctuation 
# marks unchanged.


# Input Sentence: I want to become a Data Scientist.

# Encrypt the above input sentence using the program you just created.

# Note: Convert the given input sentence into lowercase before encrypting. The final output should be 
# lowercase

# %% [markdown]
# SOL

# %%
str1= "I want to become a Data Scientist devoloper"
str1=str1.lower()

# %%
for i in range(len(str1)):
  if str1[i]=="a":
    str1 = str1.replace('a','z',i)
  elif str1[i]=="b":
    str1 = str1.replace('b','y',i)
  elif str1[i]=="c":
    str1 = str1.replace('c','x',i)
  elif str1[i]==" ":
     str1 = str1.replace(' ','$',i)

# %%
str1
# Out:
# 'i$wznt$to$yexome$z$dztz$sxientist'

# %% [markdown]
# Q1

# %%
# . Create a function which will take a list as an argument and return the product of all the numbers 
# after creating a flat list.



list1=[1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45, 
22, 61, 34)}, [56, 'data science'], 'Machine Learning']

# %%
l2=[1,2,3,(6,7,8,True)]
for i in l2:
  if type(i)==tuple:
    for j in i:
      if type(j)==bool:
        continue
      print(j)
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 6
# 7
# 8

# %%
dict1={
    1:34, 
    "key2": [55, 67, 78, 89],
     4: (45, 22, 61, 34)
     }
a1=[]
for i in dict1:
  if type(i)==int:
    a1.append(i)
for j in dict1.values():
    if type(j)==int:
      a1.append(j)
    elif type(j)==list:
      for p in j:
        a1.append(p)
    if type(j)==tuple:
      for q in j:
        a1.append(q)
print(a1)
# Out:
# [1, 4, 34, 55, 67, 78, 89, 45, 22, 61, 34]

# %%
# Out:
# None

# %%
list1=[1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45, 
22, 61, 34)}, [56, 'data science'], 'Machine Learning']

# %%
a=[]
def num1(l):
  for i in l:
    if type(i)==int:
      a.append(i)
    elif type(i)==list:
      for j in i:
        if type(j)==int:
          a.append(j)
    elif type(i)==tuple:
      for x in i:
        a.append(x)
    elif type(i)==set:
      for y in i:
        a.append(y)
    elif type(i)==dict:
      for z in i:
        if type(z)==int:
          a.append(z)
      for j1 in dict1.values():
        if type(j1)==int:
          a.append(j1)
        elif type(j1)==list:
          for p in j1:
            a.append(p)
          if type(j1)==tuple:
            for q in j1:
              a.append(q)
      for j2 in dict1.keys():
        if type(dict1[j2])==tuple:
          lstdictj2 = list(dict1[j2])
          for k in lstdictj2:
            a.append(k)
            
  return a
          

m=num1(list1)
print(m)
# Out:
# [1, 2, 3, 4, 44, 55, 66, 34, 56, 78, 89, 34, 1, 2, 3, 1, 4, 34, 55, 67, 78, 89, 45, 22, 61, 34, 56]

# %%
from functools import reduce


reduce(lambda x,y:x*y,a)
# Out:
# 4134711838987085478833841242112000

# %% [markdown]
# Q1

# %%
# Q1. Which function is used to open a file? What are the different modes of opening a file? Explain each mode 
# of file opening.

# open function is used
# read- read  afile
# append-append something to file
# write--write something to file

# %% [markdown]
# Q2

# %%
# Q2. Why close() function is used? Why is it important to close a file?

# it is used to close a file ...otherwise no other operations can work

# %% [markdown]
# Q3

# %%
# Q3. Write a python program to create a text file. Write ‘I want to become a Data Scientist’ in that file. Then 
# close the file. Open this file and read the content of the file.

f=open("Demo.txt","w")
f.write("I want to become a Data Scientist")
f.close()

with open("Demo.txt") as f:
  print(f.read())
# Out:
# I want to become a Data Scientist

# %% [markdown]
# Q4

# %%
# Q4. Explain the following with python code: read(), readline() and readlines().

with open("Rdemo.txt","w") as f :
  f.write("stinct from bacteria, their deoxyribonucleic acid, or DNA, is contained in a membrane-bound nucleus). They are thought to have evolved independently from the unicellular eukaryotes. Animals differ from members of the two other kingdoms of multicellular eukaryotes, the plants (Plantae) and the fungi (Mycota), in fundamental variations in morphology and physiology. This is largely because animals have developed muscles and hence mobility, a characteristic that has stimulated the further development of tissues and organ systems.")

with open ("Rdemo.txt","r") as f:
  print(f.readlines())
# Out:
# ['stinct from bacteria, their deoxyribonucleic acid, or DNA, is contained in a membrane-bound nucleus). They are thought to have evolved independently from the unicellular eukaryotes. Animals differ from members of the two other kingdoms of multicellular eukaryotes, the plants (Plantae) and the fungi (Mycota), in fundamental variations in morphology and physiology. This is largely because animals have developed muscles and hence mobility, a characteristic that has stimulated the further development of tissues and organ systems.']
# /n

# %%
with open ("Rdemo.txt","r") as f:
  print(f.readline(13))
# Out:
# stinct from b

# %% [markdown]
# Q5

# %%
# Q5. Explain why with statement is used with open(). What is the advantage of using with statement and 
# open() together?

# IF  we use with we can directly close the file

# %% [markdown]
# Q6

# %%
# Q6. Explain the write() and writelines() functions. Give a suitable example.

# %% [markdown]
# Write

# %%
f=open("Demo.txt","w")
f.write("I want to become a Data Scientist")
f.close()

with open("Demo.txt") as f:
  print(f.read())
# Out:
# I want to become a Data Scientist

# %% [markdown]
# writelines

# %%
file1 = open("Employees.txt", "w")
lst = []
for i in range(3):
    name = input("Enter the name of the employee: ")
    lst.append(name + '\n')
      
file1.writelines(lst)
file1.close()
# Out:
# Enter the name of the employee: harsh
# Enter the name of the employee: heta
# Enter the name of the employee: rashu

# %%
file1 = open("Employees.txt", "r")
print(file1.read())
file1.close()
# Out:
# harsh
# heta
# rashu

# %%
# . Explain why we have to use the Exception class while creating a Custom Exception.

# we need to use a exception class coz, it helps us in printing the message we want to display through our custom class
# coz custom class takes exception as a argument.

# %% [markdown]
# Q2

# %%
# Write a python program to print Python Exception Hierarchy.

# import inspect module
import inspect
  
# our treeClass function
def treeClass(cls, ind = 0):
    
      # print name of the class
    print (ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# inspect.getmro() Return a tuple 
# of class  cls’s base classes.
  
# building a tree hierarchy 
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
# 0 BaseException
# 3 BaseExceptionGroup
# 6 ExceptionGroup
# 3 Exception
# 6 ArithmeticError
# 9 FloatingPointError
# 9 OverflowError
# 9 ZeroDivisionError
# 12 DivisionByZero
# 12 DivisionUndefined
# 9 DecimalException
# 12 Clamped
# 12 Rounded
# 15 Underflow
# 15 Overflow
# 12 Inexact
# 15 Underflow
# 15 Overflow
# 12 Subnormal
# 15 Underflow
# 12 DivisionByZero
# 12 FloatOperation
# 12 InvalidOperation
# 15 ConversionSyntax
# 15 DivisionImpossible
# 15 DivisionUndefined
# 15 InvalidContext
# 6 AssertionError
# 6 AttributeError
# 9 FrozenInstanceError
# 6 BufferError
# 6 EOFError
# 9 IncompleteReadError
# 6 ImportError
# 9 ModuleNotFoundError
# 12 PackageNotFoundError
# 9 ZipImportError
# 6 LookupError
# 9 IndexError
# 9 KeyError
# 12 NoSuchKernel
# 12 UnknownBackend
# 9 CodecRegistryError
# 6 MemoryError
# 6 NameError
# 9 UnboundLocalError
# 6 OSError
# 9 BlockingIOError
# 9 ChildProcessError
# 9 ConnectionError
# 12 BrokenPipeError
# ...

# %% [markdown]
# Q3

# %%
# ariithmetic errors
# zero-division-error

try:
    a=1
    print(a/0)
except Exception as e:
    print(f"{e},{e.__class__}")
# Out:
# division by zero,<class 'ZeroDivisionError'>

# %% [markdown]
# Q4

# %%
# <!-- Why LookupError class is used? Explain with an example KeyError and IndexError. -->
# Lookup Error in Python The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively

dict1={
    "name":"Harsh",
    "age":21,
    "sex":"Male"
}
try:
  dict1["color"]
except Exception as e:
    print(f"{e},{e.__class__}")
# Out:
# 'color',<class 'KeyError'>

# %% [markdown]
# Indexerror

# %%
l1=[1,2,3,4,5]
try:
    print(l1[5])
except Exception as e:
    print(f"{e},{e.__class__}")
# Out:
# list index out of range,<class 'IndexError'>

# %% [markdown]
# Q5

# %%
# Explain ImportError. What is ModuleNotFoundError?
import pand
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Explain ImportError. What is ModuleNotFoundError?
# ----> 2 import pand
#
# ModuleNotFoundError: No module named 'pand'

# %% [markdown]
# importerror

# %%
# When we try to import a certain stuff from another file , and if its not present we get import error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 import os,sys
#       2 from os.path import dirname,join,abspath
# ----> 3 sys.path.insert(0,abspath(join(dirname(__file__),"..")))
#
# NameError: name '__file__' is not defined

# %% [markdown]
# Q6

# %%
# . List down some best practices for exception handling in python.
# I think the best way is to have as deep a hierarchy of exceptions as possible, to give maximum information to the programmer.
# always write the exception name instead of writing exception as a genralization

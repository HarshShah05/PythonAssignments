# %% [markdown]
# Q1

# %%
# What is an API? Give an example, where an API is used in real life.

# Api stands for application program interface, its basically used for 2 applications to communicate with each other.
# Real world example can be Gpay.


# APIs are mechanisms that enable two software components to communicate with each other using a set of definitions and protocols.
#  For example, the weather bureau’s software system contains daily weather data. 
#  The weather app on your phone “talks” to this system via APIs and shows you daily weather updates on your phone

# %% [markdown]
# Q2

# %%
# Give advantages and disadvantages of using API.

# Advantages

# APIs are used to integrate new applications with existing software systems

# APIs present a unique opportunity for businesses to meet their clients’ needs across different platforms.
#  For example, maps API allows map information integration via websites, Android,iOS, etc

# Easy to maintain



# Disadvantages

# Creating API is a very time-consuming process.
# Maintenance cost is very high.
# It can crash when testing API.

# %% [markdown]
# Q3

# %%
# What is a Web API? Differentiate between API and Web API.

# Web APi is a subset of Api
# Web api onlu uses http protocol,where as api uses smtp,tcp,http protocols etc.

# %% [markdown]
# Q4

# %%
# Explain REST and SOAP Architecture. Mention shortcomings of SOAP.


# REST API

# Rest stands for representaional state transfer and is flexible,scable
# These are the most popular and flexible APIs found on the web today. The client sends requests to the server as data. 
# The server uses this client input to start internal functions and returns output data back to the client.


# SOAP
# These APIs use Simple Object Access Protocol. Client and server exchange messages using XML. 
# This is a less flexible API that was more popular in the past.

# %% [markdown]
# Q5

# %%
# Differentiate between REST and SOAP.

# REST--its scalable , flexible
# Soap--its not scalable,mor flexible

# %%
# python 17th feb
# MongoDb

import pymongo

# %%
client=pymongo.MongoClient("mongodb+srv://shahharsh0512:PYTHONMONGO@cluster0.nxfjeek.mongodb.net/?retryWrites=true&w=majority")

# %%
client
# Out:
# MongoClient(host=['ac-eltb6ri-shard-00-00.nxfjeek.mongodb.net:27017', 'ac-eltb6ri-shard-00-01.nxfjeek.mongodb.net:27017', 'ac-eltb6ri-shard-00-02.nxfjeek.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-dcnh82-shard-0', tls=True)

# %% [markdown]
# Create database and collection

# %%
db=client["Pwskills"]
c1=db.Coll1

# %% [markdown]
# Inserting in database

# %%
db=client["Pwskills"]
rec=db.coll1

# %%
details={
    "Name":"Rohan",
    "Sex":"Male",
    "Age":21 
    }

# %%
rec.insert_one(details)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-27-55ad003b63d8> in <module>
# ----> 1 rec.insert_one(details)
#
# /usr/local/lib/python3.8/dist-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     626         write_concern = self._write_concern_for(session)
#     627         return InsertOneResult(
# --> 628             self._insert_one(
#     629                 document,
#     630                 ordered=True,
#
# /usr/local/lib/python3.8/dist-packages/pymongo/collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     567             _check_write_command_response(result)
#     568
# --> 569         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     570
#     571         if not isinstance(doc, RawBSONDocument):
#
# ...

# %% [markdown]
# Sir my mongodb is not running in collab and even jupyter notebook is giving a lot of issues with kernel .I tried in VSCODE and all ocmmands ran perfectly ...i will put the link of that too.
# Sry sir for inconvinience

# %%
# What is MongoDB? Explain non-relational databases in short. In which scenarios it is preferred to use 
# MongoDB over SQL databases?


# SOLUTION

# MongoDB is an open-source, non-relational database solution that is categorized as a NoSQL system and can be used for Big Data applications. 
# MongoDB was first introduced in 2009 and works with so-called collections and documents,
#  which in turn contain various key-value pairs that ultimately store the data

# Scalability is easy in NoSql rather than in sql

# %% [markdown]
# Q2

# %%
# State and Explain the features of MongoDB

# Since mongodb is a nosql it has following features

# NoSQL databases are a new generation of database technologies that are designed to provide a flexible, scalable, and reliable solution for storing and retrieving data. Among the most notable features of NoSQL databases are:

# Horizontal scalability.
# Flexible schema.
# Fast queries.
# Ease of use.

# %% [markdown]
# Q3

# %%
# . Write a code to connect MongoDB to Python. Also, create a database and a collection in MongoDB.

import pymomgo as py

# creating a connection

connectionstring="mongodb+srv://shahharsh0512:PYTHONMONGO@cluster0.nxfjeek.mongodb.net/?retryWrites=true&w=majority"
client=py.MongoClient(connectionstring)


# creating a databse
db=client["Pwskills"]


# Creating a collection c1 
c1=db.collection1

# %% [markdown]
# Q4

# %%
# Using the database and the collection created in question number 3, write a code to insert one record, 
# and insert many records. Use the find() and find_one() methods to print the inserted record.


data={
    "Name":"harsh",
    "Age":21
}

# inserting one record
c1.insert_one(data)

# %%
# inserting many

data2=[
    {"Name":'Harsh',"Age":21},
    {"Color":"Red","Vegetbale":"Tomato"},
]

c1.insert_many(data2)

# %%
# Find one

a=c1.find_one({})
print(a)

# %%
a1=c1.find({})

for i in a1:
  print(i)

# %% [markdown]
# Q5

# %%
# Explain how you can use the find() method to query the MongoDB database. Write a simple code to 
# demonstrate this.

# Find is used to find all documents in our documents and example is given in example 4

# %% [markdown]
# Q6

# %%
# Explain the sort() method. Give an example to demonstrate sorting in MongoDB.

# 1 is for ascending
# -1 is for descending

# Name is column name on which sorting is being applied

# db.books.find().sort({Name:1})---sorts in ascending order
# db.books.find().sort({Name:-1})---sorts in descending  order

# %% [markdown]
# Q7

# %%
# Explain why delete_one(), delete_many(), and drop() is used.

# delete_one==it deletes the first document which matches the condition
# delete_many==it deletes all occurences


# c1.delete_one({"Sex":"Male"})----first occurence will get deleted
# c1.delete_many({"Sex":"Male"})---all occurences will get deleted



# Drop ==used to drop a collection
# if c1 is collectin name 

# c1.drop()
